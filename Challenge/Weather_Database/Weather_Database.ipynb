# %% [markdown]
# # Weather Database

# %% [markdown]
# #### Import

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
from config import g_key

# %% [markdown]
# #### Random Latitudes & Longitudes

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip (lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# #### Find nearest cities

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %% [markdown]
# #### Weather Data for cities

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(2)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description":city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | black river
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | tazmalt
# Processing Record 5 of Set 1 | piacenza
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | grootfontein
# Processing Record 12 of Set 1 | port lincoln
# Processing Record 13 of Set 1 | kloulklubed
# Processing Record 14 of Set 1 | norrtalje
# Processing Record 15 of Set 1 | ugoofaaru
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | katsuura
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | biaora
# Processing Record 21 of Set 1 | selma
# Processing Record 22 of Set 1 | zhangye
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | gweta
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | teya
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | wolgast
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | joshimath
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | romny
# Processing Record 37 of Set 1 | salalah
# Processing Record 38 of Set 1 | taunggyi
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | yaan
# Processing Record 42 of Set 1 | ambilobe
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | dehloran
# Processing Record 45 of Set 1 | narsaq
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | campiglia marittima
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | bijar
# Processing Record 4 of Set 2 | yashkino
# Processing Record 5 of Set 2 | cap-aux-meules
# Processing Record 6 of Set 2 | vostok
# Processing Record 7 of Set 2 | alofi
# Processing Record 8 of Set 2 | ballina
# Processing Record 9 of Set 2 | kavaratti
# Processing Record 10 of Set 2 | hirado
# Processing Record 11 of Set 2 | tallahassee
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 2 | vershino-shakhtaminskiy
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | northam
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | isangel
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | stutterheim
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | vaitape
# Processing Record 24 of Set 2 | lata
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 2 | sol-iletsk
# Processing Record 27 of Set 2 | linxia
# Processing Record 28 of Set 2 | hami
# Processing Record 29 of Set 2 | puerto ayacucho
# Processing Record 30 of Set 2 | sola
# Processing Record 31 of Set 2 | biloela
# Processing Record 32 of Set 2 | cururupu
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | plettenberg bay
# Processing Record 35 of Set 2 | pochinki
# Processing Record 36 of Set 2 | tarakan
# Processing Record 37 of Set 2 | hovd
# Processing Record 38 of Set 2 | clyde river
# Processing Record 39 of Set 2 | clarence town
# Processing Record 40 of Set 2 | sao joao da barra
# Processing Record 41 of Set 2 | berlevag
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | tocopilla
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | plyussa
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | murray bridge
# Processing Record 48 of Set 2 | yerbogachen
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | matameye
# City not found. Skipping...
# Processing Record 1 of Set 3 | hell
# Processing Record 2 of Set 3 | lichtenburg
# Processing Record 3 of Set 3 | birao
# Processing Record 4 of Set 3 | cidreira
# Processing Record 5 of Set 3 | emba
# Processing Record 6 of Set 3 | ancud
# Processing Record 7 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 3 | okhotsk
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | college
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | broome
# Processing Record 13 of Set 3 | cam pha
# City not found. Skipping...
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | lethem
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | qaanaaq
# Processing Record 18 of Set 3 | emerald
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | goderich
# Processing Record 21 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 3 | jambi
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | arman
# Processing Record 25 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 3 | toulepleu
# City not found. Skipping...
# Processing Record 27 of Set 3 | durazno
# Processing Record 28 of Set 3 | rabo de peixe
# Processing Record 29 of Set 3 | miyako
# Processing Record 30 of Set 3 | arlit
# Processing Record 31 of Set 3 | ponta delgada
# Processing Record 32 of Set 3 | marsa matruh
# Processing Record 33 of Set 3 | ende
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | san patricio
# Processing Record 36 of Set 3 | muisne
# Processing Record 37 of Set 3 | kutum
# Processing Record 38 of Set 3 | katangli
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | skibbereen
# Processing Record 41 of Set 3 | zanesville
# Processing Record 42 of Set 3 | saint george
# Processing Record 43 of Set 3 | saldanha
# Processing Record 44 of Set 3 | yulara
# Processing Record 45 of Set 3 | kuala terengganu
# Processing Record 46 of Set 3 | verkhnevilyuysk
# Processing Record 47 of Set 3 | kudahuvadhoo
# Processing Record 48 of Set 3 | ribeira grande
# Processing Record 49 of Set 3 | adrar
# Processing Record 50 of Set 3 | katherine
# Processing Record 1 of Set 4 | maubin
# Processing Record 2 of Set 4 | kruisfontein
# Processing Record 3 of Set 4 | coihaique
# Processing Record 4 of Set 4 | koslan
# Processing Record 5 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 7 of Set 4 | saint-joseph
# Processing Record 8 of Set 4 | jumla
# Processing Record 9 of Set 4 | alice springs
# Processing Record 10 of Set 4 | pangody
# Processing Record 11 of Set 4 | shakawe
# Processing Record 12 of Set 4 | zheleznodorozhnyy
# Processing Record 13 of Set 4 | lompoc
# Processing Record 14 of Set 4 | robertsport
# Processing Record 15 of Set 4 | kenai
# Processing Record 16 of Set 4 | srednekolymsk
# Processing Record 17 of Set 4 | tahe
# Processing Record 18 of Set 4 | esperance
# Processing Record 19 of Set 4 | ilulissat
# Processing Record 20 of Set 4 | ust-kalmanka
# Processing Record 21 of Set 4 | inyonga
# Processing Record 22 of Set 4 | mahon
# Processing Record 23 of Set 4 | urfa
# City not found. Skipping...
# Processing Record 24 of Set 4 | verkhoyansk
# Processing Record 25 of Set 4 | luau
# Processing Record 26 of Set 4 | turayf
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | locri
# Processing Record 29 of Set 4 | nanortalik
# Processing Record 30 of Set 4 | dzerzhinskoye
# Processing Record 31 of Set 4 | sinnamary
# Processing Record 32 of Set 4 | ponta do sol
# Processing Record 33 of Set 4 | candolim
# Processing Record 34 of Set 4 | riyadh
# Processing Record 35 of Set 4 | yeppoon
# Processing Record 36 of Set 4 | solton
# Processing Record 37 of Set 4 | nhulunbuy
# Processing Record 38 of Set 4 | klaksvik
# Processing Record 39 of Set 4 | pringsewu
# Processing Record 40 of Set 4 | stornoway
# Processing Record 41 of Set 4 | taltal
# Processing Record 42 of Set 4 | sao filipe
# Processing Record 43 of Set 4 | sarangani
# Processing Record 44 of Set 4 | dunmore town
# Processing Record 45 of Set 4 | rokupr
# Processing Record 46 of Set 4 | tateyama
# Processing Record 47 of Set 4 | nikolskoye
# Processing Record 48 of Set 4 | mar del plata
# Processing Record 49 of Set 4 | kamyshla
# Processing Record 50 of Set 4 | tonantins
# Processing Record 1 of Set 5 | nanchang
# Processing Record 2 of Set 5 | dunedin
# Processing Record 3 of Set 5 | coquimbo
# Processing Record 4 of Set 5 | banjar
# Processing Record 5 of Set 5 | pueblo nuevo
# Processing Record 6 of Set 5 | beringovskiy
# Processing Record 7 of Set 5 | mandera
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | pontianak
# Processing Record 10 of Set 5 | boende
# Processing Record 11 of Set 5 | bethel
# Processing Record 12 of Set 5 | rocha
# Processing Record 13 of Set 5 | hamilton
# Processing Record 14 of Set 5 | rozvadiv
# Processing Record 15 of Set 5 | lopez mateos
# Processing Record 16 of Set 5 | provideniya
# Processing Record 17 of Set 5 | tashtagol
# Processing Record 18 of Set 5 | sumbe
# Processing Record 19 of Set 5 | ganzhou
# Processing Record 20 of Set 5 | dhidhdhoo
# Processing Record 21 of Set 5 | khingansk
# Processing Record 22 of Set 5 | aksu
# Processing Record 23 of Set 5 | general roca
# Processing Record 24 of Set 5 | sitka
# Processing Record 25 of Set 5 | pirgos
# Processing Record 26 of Set 5 | mahajanga
# Processing Record 27 of Set 5 | vanavara
# Processing Record 28 of Set 5 | ahipara
# Processing Record 29 of Set 5 | luena
# Processing Record 30 of Set 5 | anchorage
# Processing Record 31 of Set 5 | athabasca
# Processing Record 32 of Set 5 | padang
# Processing Record 33 of Set 5 | kodiak
# Processing Record 34 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 5 | ahuimanu
# Processing Record 36 of Set 5 | durango
# Processing Record 37 of Set 5 | galesong
# Processing Record 38 of Set 5 | kaitangata
# Processing Record 39 of Set 5 | conchas
# Processing Record 40 of Set 5 | hofn
# Processing Record 41 of Set 5 | novikovo
# Processing Record 42 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 43 of Set 5 | pozega
# Processing Record 44 of Set 5 | hervey bay
# Processing Record 45 of Set 5 | gallup
# Processing Record 46 of Set 5 | voyvozh
# Processing Record 47 of Set 5 | kyren
# Processing Record 48 of Set 5 | doha
# Processing Record 49 of Set 5 | eganville
# Processing Record 50 of Set 5 | salekhard
# Processing Record 1 of Set 6 | alekseyevka
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | yugorsk
# Processing Record 4 of Set 6 | balkhash
# Processing Record 5 of Set 6 | bacolod
# Processing Record 6 of Set 6 | severo-kurilsk
# Processing Record 7 of Set 6 | kemijarvi
# Processing Record 8 of Set 6 | waipawa
# Processing Record 9 of Set 6 | sosnovo-ozerskoye
# Processing Record 10 of Set 6 | asau
# Processing Record 11 of Set 6 | san quintin
# Processing Record 12 of Set 6 | cine
# Processing Record 13 of Set 6 | jieshi
# Processing Record 14 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 6 | saryozek
# Processing Record 16 of Set 6 | castlebar
# Processing Record 17 of Set 6 | darhan
# Processing Record 18 of Set 6 | togur
# Processing Record 19 of Set 6 | vilcun
# Processing Record 20 of Set 6 | midland
# Processing Record 21 of Set 6 | erhlin
# City not found. Skipping...
# Processing Record 22 of Set 6 | avarua
# Processing Record 23 of Set 6 | tuysarkan
# City not found. Skipping...
# Processing Record 24 of Set 6 | bilibino
# Processing Record 25 of Set 6 | tuktoyaktuk
# Processing Record 26 of Set 6 | adamantina
# Processing Record 27 of Set 6 | deputatskiy
# Processing Record 28 of Set 6 | ordynskoye
# Processing Record 29 of Set 6 | luderitz
# Processing Record 30 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 6 | khorixas
# Processing Record 32 of Set 6 | vestmanna
# Processing Record 33 of Set 6 | aasiaat
# Processing Record 34 of Set 6 | port macquarie
# Processing Record 35 of Set 6 | heyang
# Processing Record 36 of Set 6 | rockport
# Processing Record 37 of Set 6 | praia
# Processing Record 38 of Set 6 | mahebourg
# Processing Record 39 of Set 6 | at-bashi
# Processing Record 40 of Set 6 | aykhal
# Processing Record 41 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 42 of Set 6 | bathsheba
# Processing Record 43 of Set 6 | mulege
# Processing Record 44 of Set 6 | am timan
# Processing Record 45 of Set 6 | maragogi
# Processing Record 46 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 6 | winton
# Processing Record 48 of Set 6 | prince rupert
# Processing Record 49 of Set 6 | cortez
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | cherskiy
# Processing Record 2 of Set 7 | bambous virieux
# Processing Record 3 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 4 of Set 7 | semnan
# Processing Record 5 of Set 7 | zlocieniec
# Processing Record 6 of Set 7 | eureka
# Processing Record 7 of Set 7 | pitimbu
# Processing Record 8 of Set 7 | leningradskiy
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | port blair
# Processing Record 11 of Set 7 | shenjiamen
# Processing Record 12 of Set 7 | halacho
# Processing Record 13 of Set 7 | altamont
# Processing Record 14 of Set 7 | guadalupe
# Processing Record 15 of Set 7 | sobolevo
# Processing Record 16 of Set 7 | markova
# Processing Record 17 of Set 7 | port hedland
# Processing Record 18 of Set 7 | safaga
# Processing Record 19 of Set 7 | umm kaddadah
# Processing Record 20 of Set 7 | cam ranh
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | russell
# Processing Record 23 of Set 7 | marzuq
# Processing Record 24 of Set 7 | dawson creek
# Processing Record 25 of Set 7 | eenhana
# Processing Record 26 of Set 7 | rumford
# Processing Record 27 of Set 7 | ketchikan
# Processing Record 28 of Set 7 | pevek
# Processing Record 29 of Set 7 | puerto suarez
# Processing Record 30 of Set 7 | xining
# Processing Record 31 of Set 7 | othonoi
# City not found. Skipping...
# Processing Record 32 of Set 7 | saskylakh
# Processing Record 33 of Set 7 | nola
# Processing Record 34 of Set 7 | djambala
# Processing Record 35 of Set 7 | luebo
# Processing Record 36 of Set 7 | pangnirtung
# Processing Record 37 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 38 of Set 7 | kishtwar
# Processing Record 39 of Set 7 | atka
# City not found. Skipping...
# Processing Record 40 of Set 7 | rawson
# Processing Record 41 of Set 7 | buarcos
# Processing Record 42 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 7 | bonavista
# Processing Record 44 of Set 7 | poum
# Processing Record 45 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 7 | oriximina
# Processing Record 47 of Set 7 | dingle
# Processing Record 48 of Set 7 | beloha
# Processing Record 49 of Set 7 | aswan
# Processing Record 50 of Set 7 | riberalta
# Processing Record 1 of Set 8 | upington
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | sainte-marie
# Processing Record 4 of Set 8 | pecos
# Processing Record 5 of Set 8 | hauterive
# Processing Record 6 of Set 8 | maniwaki
# Processing Record 7 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 8 | tessalit
# Processing Record 9 of Set 8 | buliwao
# Processing Record 10 of Set 8 | puerto madero
# Processing Record 11 of Set 8 | sibolga
# Processing Record 12 of Set 8 | cap malheureux
# Processing Record 13 of Set 8 | faanui
# Processing Record 14 of Set 8 | berea
# Processing Record 15 of Set 8 | gagino
# Processing Record 16 of Set 8 | roebourne
# Processing Record 17 of Set 8 | karratha
# Processing Record 18 of Set 8 | qandala
# Processing Record 19 of Set 8 | norman wells
# Processing Record 20 of Set 8 | ostrovnoy
# Processing Record 21 of Set 8 | yumen
# Processing Record 22 of Set 8 | marienburg
# Processing Record 23 of Set 8 | hilo
# Processing Record 24 of Set 8 | porto novo
# Processing Record 25 of Set 8 | sungaipenuh
# Processing Record 26 of Set 8 | khani
# Processing Record 27 of Set 8 | lieksa
# Processing Record 28 of Set 8 | west wendover
# Processing Record 29 of Set 8 | lensk
# Processing Record 30 of Set 8 | monastyrshchina
# Processing Record 31 of Set 8 | fukue
# Processing Record 32 of Set 8 | biak
# Processing Record 33 of Set 8 | lagoa
# Processing Record 34 of Set 8 | kembe
# Processing Record 35 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 8 | ilhabela
# Processing Record 37 of Set 8 | bandarbeyla
# Processing Record 38 of Set 8 | milledgeville
# Processing Record 39 of Set 8 | jiangyou
# Processing Record 40 of Set 8 | sabinas hidalgo
# Processing Record 41 of Set 8 | archdale
# Processing Record 42 of Set 8 | copperas cove
# Processing Record 43 of Set 8 | ndola
# Processing Record 44 of Set 8 | talnakh
# Processing Record 45 of Set 8 | ganganagar
# Processing Record 46 of Set 8 | poyarkovo
# Processing Record 47 of Set 8 | paducah
# Processing Record 48 of Set 8 | tigil
# Processing Record 49 of Set 8 | vanimo
# Processing Record 50 of Set 8 | tezu
# Processing Record 1 of Set 9 | fairbanks
# Processing Record 2 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 9 | inhambane
# Processing Record 4 of Set 9 | manzanillo
# Processing Record 5 of Set 9 | takoradi
# Processing Record 6 of Set 9 | gamba
# Processing Record 7 of Set 9 | kaoma
# Processing Record 8 of Set 9 | lalibela
# Processing Record 9 of Set 9 | upernavik
# Processing Record 10 of Set 9 | touros
# Processing Record 11 of Set 9 | umea
# Processing Record 12 of Set 9 | gull lake
# Processing Record 13 of Set 9 | zhigansk
# Processing Record 14 of Set 9 | puerto del rosario
# Processing Record 15 of Set 9 | herran
# Processing Record 16 of Set 9 | grindavik
# Processing Record 17 of Set 9 | toora-khem
# Processing Record 18 of Set 9 | atar
# Processing Record 19 of Set 9 | nirasaki
# Processing Record 20 of Set 9 | machiques
# Processing Record 21 of Set 9 | vardo
# Processing Record 22 of Set 9 | leh
# Processing Record 23 of Set 9 | quatre cocos
# Processing Record 24 of Set 9 | codrington
# Processing Record 25 of Set 9 | hun
# Processing Record 26 of Set 9 | garachine
# Processing Record 27 of Set 9 | bahia blanca
# Processing Record 28 of Set 9 | ixtapa
# Processing Record 29 of Set 9 | brigantine
# Processing Record 30 of Set 9 | ciudad bolivar
# Processing Record 31 of Set 9 | tharrawaddy
# City not found. Skipping...
# Processing Record 32 of Set 9 | lianzhou
# Processing Record 33 of Set 9 | mvangue
# Processing Record 34 of Set 9 | airai
# Processing Record 35 of Set 9 | urulga
# City not found. Skipping...
# Processing Record 36 of Set 9 | saint-pierre
# Processing Record 37 of Set 9 | kapit
# Processing Record 38 of Set 9 | alta floresta
# Processing Record 39 of Set 9 | huarmey
# Processing Record 40 of Set 9 | selikhino
# Processing Record 41 of Set 9 | moose factory
# Processing Record 42 of Set 9 | kununurra
# Processing Record 43 of Set 9 | pinczow
# Processing Record 44 of Set 9 | taiyuan
# Processing Record 45 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 9 | camacha
# Processing Record 47 of Set 9 | nantucket
# Processing Record 48 of Set 9 | flinders
# Processing Record 49 of Set 9 | saint anthony
# Processing Record 50 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 10 | chukhloma
# Processing Record 2 of Set 10 | atambua
# Processing Record 3 of Set 10 | coxim
# Processing Record 4 of Set 10 | bilma
# Processing Record 5 of Set 10 | kirakira
# Processing Record 6 of Set 10 | port hawkesbury
# Processing Record 7 of Set 10 | pital
# Processing Record 8 of Set 10 | lakatoro
# Processing Record 9 of Set 10 | qasigiannguit
# Processing Record 10 of Set 10 | taoudenni
# Processing Record 11 of Set 10 | dormidontovka
# Processing Record 12 of Set 10 | uray
# Processing Record 13 of Set 10 | san carlos de bariloche
# Processing Record 14 of Set 10 | whitehorse
# Processing Record 15 of Set 10 | pathein
# Processing Record 16 of Set 10 | villamontes
# Processing Record 17 of Set 10 | mehamn
# Processing Record 18 of Set 10 | erie
# Processing Record 19 of Set 10 | hobyo
# Processing Record 20 of Set 10 | solnechnyy
# Processing Record 21 of Set 10 | sayat
# Processing Record 22 of Set 10 | kisangani
# Processing Record 23 of Set 10 | aden
# Processing Record 24 of Set 10 | okato
# Processing Record 25 of Set 10 | brownsville
# Processing Record 26 of Set 10 | coahuayana
# Processing Record 27 of Set 10 | comodoro rivadavia
# Processing Record 28 of Set 10 | greenville
# Processing Record 29 of Set 10 | khislavichi
# Processing Record 30 of Set 10 | sinjah
# City not found. Skipping...
# Processing Record 31 of Set 10 | lufilufi
# Processing Record 32 of Set 10 | spoleto
# Processing Record 33 of Set 10 | sabha
# Processing Record 34 of Set 10 | shitkino
# Processing Record 35 of Set 10 | tabou
# Processing Record 36 of Set 10 | tefe
# Processing Record 37 of Set 10 | thabazimbi
# Processing Record 38 of Set 10 | dankov
# Processing Record 39 of Set 10 | okha
# Processing Record 40 of Set 10 | odienne
# Processing Record 41 of Set 10 | toppenish
# Processing Record 42 of Set 10 | christiana
# Processing Record 43 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 44 of Set 10 | mattru
# Processing Record 45 of Set 10 | atbasar
# Processing Record 46 of Set 10 | wismar
# Processing Record 47 of Set 10 | teluk nibung
# Processing Record 48 of Set 10 | chastoozerye
# City not found. Skipping...
# Processing Record 49 of Set 10 | algiers
# Processing Record 50 of Set 10 | kovdor
# Processing Record 1 of Set 11 | canico
# Processing Record 2 of Set 11 | neiafu
# Processing Record 3 of Set 11 | golden
# Processing Record 4 of Set 11 | tilichiki
# Processing Record 5 of Set 11 | palmer
# Processing Record 6 of Set 11 | port augusta
# Processing Record 7 of Set 11 | fairfield
# Processing Record 8 of Set 11 | macomb
# Processing Record 9 of Set 11 | lola
# Processing Record 10 of Set 11 | fortuna
# Processing Record 11 of Set 11 | mananjary
# Processing Record 12 of Set 11 | kharabali
# Processing Record 13 of Set 11 | saint-denis
# Processing Record 14 of Set 11 | usvyaty
# Processing Record 15 of Set 11 | araria
# Processing Record 16 of Set 11 | namwala
# Processing Record 17 of Set 11 | krasnoselkup
# Processing Record 18 of Set 11 | inongo
# Processing Record 19 of Set 11 | nago
# Processing Record 20 of Set 11 | tazovskiy
# Processing Record 21 of Set 11 | salinas
# Processing Record 22 of Set 11 | bairiki
# Processing Record 23 of Set 11 | mawlaik
# Processing Record 24 of Set 11 | keskin
# Processing Record 25 of Set 11 | constitucion
# Processing Record 26 of Set 11 | harper
# Processing Record 27 of Set 11 | mount gambier
# Processing Record 28 of Set 11 | marsh harbour
# Processing Record 29 of Set 11 | esil
# Processing Record 30 of Set 11 | roald
# Processing Record 31 of Set 11 | pundaguitan
# Processing Record 32 of Set 11 | afyonkarahisar
# Processing Record 33 of Set 11 | lanzhou
# Processing Record 34 of Set 11 | kahului
# Processing Record 35 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 36 of Set 11 | khurda
# Processing Record 37 of Set 11 | springbok
# Processing Record 38 of Set 11 | baiao
# Processing Record 39 of Set 11 | tsaratanana
# Processing Record 40 of Set 11 | pingliang
# Processing Record 41 of Set 11 | kurilsk
# Processing Record 42 of Set 11 | flers
# Processing Record 43 of Set 11 | ostersund
# Processing Record 44 of Set 11 | mujiayingzi
# Processing Record 45 of Set 11 | ouango
# Processing Record 46 of Set 11 | tapiramuta
# Processing Record 47 of Set 11 | grand gaube
# Processing Record 48 of Set 11 | midyat
# Processing Record 49 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 50 of Set 11 | whitianga
# Processing Record 1 of Set 12 | saint-francois
# Processing Record 2 of Set 12 | arai
# Processing Record 3 of Set 12 | qui nhon
# Processing Record 4 of Set 12 | marawi
# Processing Record 5 of Set 12 | rawlins
# Processing Record 6 of Set 12 | sitrah
# Processing Record 7 of Set 12 | rehoboth
# Processing Record 8 of Set 12 | avera
# Processing Record 9 of Set 12 | sioux lookout
# Processing Record 10 of Set 12 | muros
# Processing Record 11 of Set 12 | lat yao
# Processing Record 12 of Set 12 | misratah
# Processing Record 13 of Set 12 | winchester
# Processing Record 14 of Set 12 | boyolangu
# Processing Record 15 of Set 12 | nuuk
# Processing Record 16 of Set 12 | amga
# Processing Record 17 of Set 12 | plouzane
# Processing Record 18 of Set 12 | nagua
# Processing Record 19 of Set 12 | cockburn town
# Processing Record 20 of Set 12 | vestmannaeyjar
# Processing Record 21 of Set 12 | laguna
# Processing Record 22 of Set 12 | khonsa
# Processing Record 23 of Set 12 | buin
# Processing Record 24 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 12 | brodokalmak
# Processing Record 26 of Set 12 | bouna
# Processing Record 27 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 12 | taihe
# Processing Record 29 of Set 12 | banamba
# Processing Record 30 of Set 12 | morgan city
# Processing Record 31 of Set 12 | havoysund
# Processing Record 32 of Set 12 | moa
# Processing Record 33 of Set 12 | lavrentiya
# Processing Record 34 of Set 12 | whitefish
# Processing Record 35 of Set 12 | tuatapere
# Processing Record 36 of Set 12 | cabras
# Processing Record 37 of Set 12 | manzhouli
# Processing Record 38 of Set 12 | outjo
# Processing Record 39 of Set 12 | havre-saint-pierre
# Processing Record 40 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 12 | mogadishu
# Processing Record 42 of Set 12 | truth or consequences
# Processing Record 43 of Set 12 | sanming
# Processing Record 44 of Set 12 | geraldton
# Processing Record 45 of Set 12 | kalmunai
# Processing Record 46 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 12 | ayakudi
# Processing Record 48 of Set 12 | arcachon
# Processing Record 49 of Set 12 | taylorville
# Processing Record 50 of Set 12 | nadym
# Processing Record 1 of Set 13 | santa cruz
# Processing Record 2 of Set 13 | rawah
# Processing Record 3 of Set 13 | san matias
# Processing Record 4 of Set 13 | zavoi
# Processing Record 5 of Set 13 | wellington
# Processing Record 6 of Set 13 | mount barker
# Processing Record 7 of Set 13 | mazagao
# Processing Record 8 of Set 13 | sabzevar
# Processing Record 9 of Set 13 | olafsvik
# Processing Record 10 of Set 13 | alugan
# Processing Record 11 of Set 13 | loandjili
# Processing Record 12 of Set 13 | lazaro cardenas
# Processing Record 13 of Set 13 | skjervoy
# Processing Record 14 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 13 | salina
# Processing Record 16 of Set 13 | fasa
# Processing Record 17 of Set 13 | banda aceh
# Processing Record 18 of Set 13 | damascus
# Processing Record 19 of Set 13 | bardiyah
# Processing Record 20 of Set 13 | dombarovskiy
# Processing Record 21 of Set 13 | novobirilyussy
# Processing Record 22 of Set 13 | kristiinankaupunki
# Processing Record 23 of Set 13 | naze
# Processing Record 24 of Set 13 | agropoli
# Processing Record 25 of Set 13 | mayo
# Processing Record 26 of Set 13 | irece
# Processing Record 27 of Set 13 | glenwood springs
# Processing Record 28 of Set 13 | puerto asis
# Processing Record 29 of Set 13 | evanton
# Processing Record 30 of Set 13 | mount isa
# Processing Record 31 of Set 13 | vao
# Processing Record 32 of Set 13 | dali
# Processing Record 33 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 13 | guerrero negro
# Processing Record 35 of Set 13 | kango
# Processing Record 36 of Set 13 | santiago del estero
# Processing Record 37 of Set 13 | mala
# Processing Record 38 of Set 13 | shahreza
# Processing Record 39 of Set 13 | el tigre
# Processing Record 40 of Set 13 | chapais
# Processing Record 41 of Set 13 | cartagena
# Processing Record 42 of Set 13 | ishigaki
# Processing Record 43 of Set 13 | high level
# Processing Record 44 of Set 13 | mpika
# Processing Record 45 of Set 13 | kostomuksha
# Processing Record 46 of Set 13 | ucluelet
# Processing Record 47 of Set 13 | otacilio costa
# Processing Record 48 of Set 13 | gumdag
# Processing Record 49 of Set 13 | marrakesh
# Processing Record 50 of Set 13 | poplar bluff
# Processing Record 1 of Set 14 | lerwick
# Processing Record 2 of Set 14 | ulladulla
# Processing Record 3 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 14 | umm lajj
# Processing Record 5 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 14 | pacific grove
# Processing Record 7 of Set 14 | mentougou
# Processing Record 8 of Set 14 | spirit river
# Processing Record 9 of Set 14 | rulenge
# Processing Record 10 of Set 14 | badhni kalan
# Processing Record 11 of Set 14 | los llanos de aridane
# Processing Record 12 of Set 14 | new york
# Processing Record 13 of Set 14 | sai buri
# Processing Record 14 of Set 14 | conceicao do araguaia
# Processing Record 15 of Set 14 | rubbestadneset
# Processing Record 16 of Set 14 | pozo colorado
# Processing Record 17 of Set 14 | tarauaca
# Processing Record 18 of Set 14 | kieta
# Processing Record 19 of Set 14 | cayenne
# Processing Record 20 of Set 14 | nabire
# Processing Record 21 of Set 14 | moindou
# Processing Record 22 of Set 14 | sabang
# Processing Record 23 of Set 14 | punta alta
# Processing Record 24 of Set 14 | richards bay
# Processing Record 25 of Set 14 | ambunti
# Processing Record 26 of Set 14 | aksarka
# Processing Record 27 of Set 14 | nome
# Processing Record 28 of Set 14 | olinda
# Processing Record 29 of Set 14 | portland
# Processing Record 30 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 14 | tura
# Processing Record 32 of Set 14 | menongue
# Processing Record 33 of Set 14 | hastings
# Processing Record 34 of Set 14 | mikhaylovka
# Processing Record 35 of Set 14 | narrabri
# Processing Record 36 of Set 14 | san-pedro
# Processing Record 37 of Set 14 | port lavaca
# Processing Record 38 of Set 14 | mwinilunga
# Processing Record 39 of Set 14 | sinop
# Processing Record 40 of Set 14 | barcelos
# Processing Record 41 of Set 14 | westport
# Processing Record 42 of Set 14 | paulo afonso
# Processing Record 43 of Set 14 | natulongan
# City not found. Skipping...
# Processing Record 44 of Set 14 | auki
# Processing Record 45 of Set 14 | puerto carreno
# Processing Record 46 of Set 14 | kaeo
# Processing Record 47 of Set 14 | falaleu
# City not found. Skipping...
# Processing Record 48 of Set 14 | vila velha
# Processing Record 49 of Set 14 | chifeng
# Processing Record 50 of Set 14 | scottsbluff
# Processing Record 1 of Set 15 | kardailovo
# Processing Record 2 of Set 15 | fort-shevchenko
# Processing Record 3 of Set 15 | natal
# Processing Record 4 of Set 15 | dodge city
# Processing Record 5 of Set 15 | manaus
# Processing Record 6 of Set 15 | champerico
# Processing Record 7 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 15 | west plains
# Processing Record 9 of Set 15 | libreville
# Processing Record 10 of Set 15 | radviliskis
# Processing Record 11 of Set 15 | jalu
# Processing Record 12 of Set 15 | bowen
# Processing Record 13 of Set 15 | singaparna
# Processing Record 14 of Set 15 | nchelenge
# Processing Record 15 of Set 15 | nelson bay
# Processing Record 16 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 17 of Set 15 | ivybridge
# Processing Record 18 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 15 | huilong
# Processing Record 20 of Set 15 | mangan
# Processing Record 21 of Set 15 | kyabram
# Processing Record 22 of Set 15 | rio gallegos
# Processing Record 23 of Set 15 | pochutla
# Processing Record 24 of Set 15 | lumphat
# Processing Record 25 of Set 15 | indianola
# Processing Record 26 of Set 15 | cuiluan
# Processing Record 27 of Set 15 | davila
# Processing Record 28 of Set 15 | baykit
# Processing Record 29 of Set 15 | tiznit
# Processing Record 30 of Set 15 | santiago
# Processing Record 31 of Set 15 | zhanakorgan
# Processing Record 32 of Set 15 | impfondo
# Processing Record 33 of Set 15 | pangai
# Processing Record 34 of Set 15 | batagay-alyta
# Processing Record 35 of Set 15 | tautira
# Processing Record 36 of Set 15 | coolum beach
# Processing Record 37 of Set 15 | zhezkazgan
# Processing Record 38 of Set 15 | apiai
# Processing Record 39 of Set 15 | dukat
# Processing Record 40 of Set 15 | maryville
# Processing Record 41 of Set 15 | puerto baquerizo moreno
# Processing Record 42 of Set 15 | haverfordwest
# Processing Record 43 of Set 15 | portici
# Processing Record 44 of Set 15 | cacu
# Processing Record 45 of Set 15 | colon
# Processing Record 46 of Set 15 | antofagasta
# Processing Record 47 of Set 15 | sakskobing
# Processing Record 48 of Set 15 | tshane
# Processing Record 49 of Set 15 | severo-yeniseyskiy
# Processing Record 50 of Set 15 | avanigadda
# Processing Record 1 of Set 16 | el faiyum
# City not found. Skipping...
# Processing Record 2 of Set 16 | viesite
# Processing Record 3 of Set 16 | the valley
# Processing Record 4 of Set 16 | vicosa
# Processing Record 5 of Set 16 | jishou
# Processing Record 6 of Set 16 | chipinge
# Processing Record 7 of Set 16 | ndiekro
# City not found. Skipping...
# Processing Record 8 of Set 16 | viedma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Castro -24.7911  -50.0119     56.84        86          99
# 1   Black River  18.0264  -77.8487     83.88        66          13
# 2     Busselton -33.6500  115.3333     58.12        73         100
# 3       Tazmalt  36.3868    4.3989     71.56        63          10
# 4      Piacenza  45.0468    9.6994     63.97        74          30
# 5    Chokurdakh  70.6333  147.9167     14.09        92          99
# 6        Albany  42.6001  -73.9662     79.45        62          97
# 7    Butaritari   3.0707  172.7902     80.82        74          13
# 8        Barrow  71.2906 -156.7887     28.42        86         100
# 9  Grootfontein -19.5667   18.1167     45.97        71           1
#
#    Wind Speed Country       Description                 Date
# 0        1.99      BR   overcast clouds  2022-05-14 22:07:16
# 1       15.59      JM        few clouds  2022-05-14 22:16:17
# 2        5.73      AU   overcast clouds  2022-05-14 22:04:06
# 3        2.01      DZ         clear sky  2022-05-14 22:16:18
# 4        2.75      IT  scattered clouds  2022-05-14 22:15:19
# 5        2.08      RU   overcast clouds  2022-05-14 22:16:20
# 6        1.99      US   overcast clouds  2022-05-14 22:06:40
# 7        9.24      KI        few clouds  2022-05-14 22:06:35
# 8       16.11      US   overcast clouds  2022-05-14 22:06:25
# 9        1.14      NA         clear sky  2022-05-14 22:16:22

# %%
new_column_order =["City",'Country','Date','Lat','Lng',"Max Temp",'Humidity','Cloudiness', 'Wind Speed','Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0        Castro      BR  2022-05-14 22:07:16 -24.7911  -50.0119     56.84
# 1   Black River      JM  2022-05-14 22:16:17  18.0264  -77.8487     83.88
# 2     Busselton      AU  2022-05-14 22:04:06 -33.6500  115.3333     58.12
# 3       Tazmalt      DZ  2022-05-14 22:16:18  36.3868    4.3989     71.56
# 4      Piacenza      IT  2022-05-14 22:15:19  45.0468    9.6994     63.97
# 5    Chokurdakh      RU  2022-05-14 22:16:20  70.6333  147.9167     14.09
# 6        Albany      US  2022-05-14 22:06:40  42.6001  -73.9662     79.45
# 7    Butaritari      KI  2022-05-14 22:06:35   3.0707  172.7902     80.82
# 8        Barrow      US  2022-05-14 22:06:25  71.2906 -156.7887     28.42
# 9  Grootfontein      NA  2022-05-14 22:16:22 -19.5667   18.1167     45.97
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        86          99        1.99   overcast clouds
# 1        66          13       15.59        few clouds
# 2        73         100        5.73   overcast clouds
# 3        63          10        2.01         clear sky
# 4        74          30        2.75  scattered clouds
# 5        92          99        2.08   overcast clouds
# 6        62          97        1.99   overcast clouds
# 7        74          13        9.24        few clouds
# 8        86         100       16.11   overcast clouds
# 9        71           1        1.14         clear sky

# %%
city_data_df = city_data_df.rename(columns={"Description":"Current Weather"})
city_data_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0       Castro      BR  2022-05-14 22:07:16 -24.7911  -50.0119     56.84
# 1  Black River      JM  2022-05-14 22:16:17  18.0264  -77.8487     83.88
# 2    Busselton      AU  2022-05-14 22:04:06 -33.6500  115.3333     58.12
# 3      Tazmalt      DZ  2022-05-14 22:16:18  36.3868    4.3989     71.56
# 4     Piacenza      IT  2022-05-14 22:15:19  45.0468    9.6994     63.97
#
#    Humidity  Cloudiness  Wind Speed   Current Weather
# 0        86          99        1.99   overcast clouds
# 1        66          13       15.59        few clouds
# 2        73         100        5.73   overcast clouds
# 3        63          10        2.01         clear sky
# 4        74          30        2.75  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
